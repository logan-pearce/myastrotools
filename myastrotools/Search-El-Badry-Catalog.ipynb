# %%
from myastrotools.tools import LoadElBadryCatalog
cat = LoadElBadryCatalog()
cat
# Out:
#                 solution_id1         solution_id2           source_id1  \
# 0        1636042515805110273  1636042515805110273  4282339100022417152
# 1        1636042515805110273  1636042515805110273  4089436931798712576
# 2        1636042515805110273  1636042515805110273  4282722760856124416
# 3        1636042515805110273  1636042515805110273  4128188325747199104
# 4        1636042515805110273  1636042515805110273  4281789722159307520
# ...                      ...                  ...                  ...
# 1817589  1636042515805110273  1636042515805110273  6056105102327466368
# 1817590  1636042515805110273  1636042515805110273  6056106511076709632
# 1817591  1636042515805110273  1636042515805110273  6056107301350695808
# 1817592  1636042515805110273  1636042515805110273  6056106992113048832
# 1817593  1636042515805110273  1636042515805110273  6056109088021357824
#
#                   source_id2  random_index1  random_index2  ref_epoch1  \
# ...

# %%
help(LoadElBadryCatalog)
# Out:
# Help on function LoadElBadryCatalog in module myastrotools.tools:
#
# LoadElBadryCatalog()
#     Load the catalog of Common Proper Motion objects in Gaia EDR3 from
#     El-Badry et al. 2021 (https://zenodo.org/record/4435257#.YfmZ0_XMKCw) into
#     a pandas DataFrame.

# %%
sourceid1 = 5240643988513309952
sourceid2 = 5240643988513310592
print(np.where(cat['source_id1'] == sourceid1))
print(np.where(cat['source_id2'] == sourceid1))
print(np.where(cat['source_id1'] == sourceid2))
print(np.where(cat['source_id2'] == sourceid2))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
cat.loc[737726]['pairdistance']*u.deg.to(u.arcsec), cat.loc[737726]['sep_AU'], cat.loc[737726]['R_chance_align']
# Out:
# (5.966515965911174, 292.8439478717294, 1.200063531272505e-06)

# %%
print([c for c in cat.columns])
# Out:
# ['solution_id1', 'solution_id2', 'source_id1', 'source_id2', 'random_index1', 'random_index2', 'ref_epoch1', 'ref_epoch2', 'ra1', 'ra2', 'ra_error1', 'ra_error2', 'dec1', 'dec2', 'dec_error1', 'dec_error2', 'parallax1', 'parallax2', 'parallax_error1', 'parallax_error2', 'parallax_over_error1', 'parallax_over_error2', 'pm1', 'pm2', 'pmra1', 'pmra2', 'pmra_error1', 'pmra_error2', 'pmdec1', 'pmdec2', 'pmdec_error1', 'pmdec_error2', 'ra_dec_corr1', 'ra_dec_corr2', 'ra_parallax_corr1', 'ra_parallax_corr2', 'ra_pmra_corr1', 'ra_pmra_corr2', 'ra_pmdec_corr1', 'ra_pmdec_corr2', 'dec_parallax_corr1', 'dec_parallax_corr2', 'dec_pmra_corr1', 'dec_pmra_corr2', 'dec_pmdec_corr1', 'dec_pmdec_corr2', 'parallax_pmra_corr1', 'parallax_pmra_corr2', 'parallax_pmdec_corr1', 'parallax_pmdec_corr2', 'pmra_pmdec_corr1', 'pmra_pmdec_corr2', 'astrometric_n_obs_al1', 'astrometric_n_obs_al2', 'astrometric_n_obs_ac1', 'astrometric_n_obs_ac2', 'astrometric_n_good_obs_al1', 'astrometric_n_good_obs_al2', 'astromet
# ...
